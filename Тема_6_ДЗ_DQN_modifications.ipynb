# %% [markdown]
# # CartPole with DQN algorithm + TargetQ + ReplayBuffer
#
# Этот пример демонстрирует применение алгоритма DQN для задачи обучения агента на среде CartPole-v1 из пакета Gymnasium на базе PyTorch.
#
# Original link: https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html#dqn-algorithm

# %% [markdown]
# ## Imports

# %%
# pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121
# pip install swig
# pip install gymnasium[box2d]

# %%
import gymnasium as gym
import math
import random
import numpy as np
import pylab
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

from tqdm import tqdm

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.zeros(1).cuda()
# Out:
# tensor([0.], device='cuda:0')

# %%
torch.__version__
# Out:
# '2.3.0+cu121'

# %%
gym.__version__
# Out:
# '0.29.1'

# %%
import tensorflow as tf

# %%
def get_available_gpus():
        physical_gpus = tf.config.list_physical_devices(device_type="GPU")
        return [(x, tf.config.experimental.get_device_details(x)) for x in physical_gpus]
    
get_available_gpus()
# Out:
# [(PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#   {'device_name': 'DML'}),
#  (PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'),
#   {'device_name': 'DML'})]

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  2

# %% [markdown]
# Когда агент наблюдает за текущим состоянием среды и выбирает действие, среда переходит в новое состояние, а также возвращает вознаграждение, указывающее на последствия этого действия. В данной задаче награда равна +1 за каждый инкрементный временной шаг, и среда завершается, если шест падает слишком далеко или тележка удаляется от центра более чем на 2,4 единицы. Это означает, что сценарии с лучшими результатами будут выполняться дольше, накапливая большую отдачу.
#
# Задача CartPole построена таким образом, что входными данными для агента являются 4 реальных значения, представляющие состояние среды (положение, скорость и т.д.). Мы берем эти 4 входных сигнала без какого-либо масштабирования и пропускаем их через небольшую полносвязную сеть с 2 выходами, по одному на каждое действие. Сеть обучается предсказывать ожидаемое значение для каждого действия с учетом входного состояния. Затем выбирается действие с наибольшим ожидаемым значением.
#
# ### Replay Memory
#
# Для обучения DQN мы будем использовать Replay Memory. В ней хранятся переходы, которые наблюдал агент, что позволяет нам использовать эти данные в дальнейшем. Переходы извлекаются путем случайной выборки, что позволяет избежать корреляции между наблюдениями. Это значительно стабилизирует и улучшает процедуру обучения DQN.
#
# Для этого нам понадобятся два класса:
#
# `Transition` - именованный кортеж, представляющий один переход в нашем окружении. По сути, он сопоставляет пары (состояние, действие) с их результатом (следующее_состояние, награда), причем состояние - это изображение разницы на экране.
#
# `ReplayMemory` - циклический буфер ограниченного размера, в котором хранятся переходы. В нем также реализован метод `.sample()` для выбора случайной выборки переходов для обучения.

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class ReplayMemory_GPU(object):

    def __init__(self, capacity, device):
        self.memory = deque([], maxlen=capacity)
        self.device = device #torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def push(self, *args):
        """Save a transition"""
        transition = Transition(*args)
        if any(element is None for element in transition if element is not None):
            raise ValueError("Transition contains None values except for terminal state")
        transition = transition._replace(state=torch.tensor(transition.state, dtype=torch.float32).to(self.device) if transition.state is not None else None)
        transition = transition._replace(action=torch.tensor(transition.action, dtype=torch.int64).to(self.device) if transition.action is not None else None)
        transition = transition._replace(next_state=torch.tensor(transition.next_state, dtype=torch.float32).to(self.device) if transition.next_state is not None else None)
        transition = transition._replace(reward=torch.tensor(transition.reward, dtype=torch.float32).to(self.device) if transition.reward is not None else None)
        self.memory.append(transition)

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# Наша модель будет представлять собой нейронную сеть, которая учитывает разницу между текущим и предыдущим экранами. Она имеет два выхода, представляющих собой $Q(s,left)$ и $Q(s,right)$ (где $s$ - вход сети). По сути, сеть пытается предсказать ожидаемую прибыль от каждого действия с учетом текущих входных данных.

# %%
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128*4)
        self.layer2 = nn.Linear(128*4, 128*4)
        self.layer3 = nn.Linear(128*4, 128*4)
        self.layer4 = nn.Linear(128*4, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.relu(self.layer3(x))
        return self.layer4(x)

# %% [markdown]
# ## Training
#
# ### Hyperparameters and utilities
#
# Далее мы инициализируем модель и ее оптимизатор, а также определяем некоторые утилиты:
#
# `select_action` - выбор действия в соответствии с эпсилон-жадной политикой. Проще говоря, иногда мы будем использовать нашу модель для выбора действия, а иногда - просто равномерную выборку. Вероятность выбора случайного действия будет начинаться с `EPS_START` и экспоненциально убывать по направлению к `EPS_END`. `EPS_DECAY` управляет скоростью затухания.
#
# `plot_durations` - помощник для построения графика продолжительности эпизодов, а также среднего значения за последние 100 эпизодов (показатель, используемый в оценках). График будет находиться под ячейкой, содержащей основной цикл обучения, и обновляться после каждого эпизода. По умолчанию продолжительность эпизода в CartPole 500 действий. Если обученный агент сможет удержать шест вертикально на протяжении 500 эпизодов - можно считать, что он хорошо обучился.

# %%
# BATCH_SIZE - количество эпизодов, отобранных из буфера воспроизведения
# GAMMA - коэффициент дисконтирования
# EPS_START - начальное значение эпсилон
# EPS_END - конечное значение эпсилон
# EPS_DECAY - скорость экспоненциального спада эпсилон, чем больше - тем медленнее падение
# TAU - скорость обновления целевой сети
# LR - скорость обучения оптимизатора ``AdamW``.

#BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4
FULL_MEMORY_LENGTH = 10000

# Среда
#env = gym.make("CartPole-v1")
env = gym.make(
    "LunarLander-v2",
    continuous = False,
    gravity = -10.0,
    enable_wind = False,
    wind_power = 15.0,
    turbulence_power = 1.5,
)

# Получить число действий
n_actions = env.action_space.n
# Получить число степеней свободы состояний
state, info = env.reset()
n_observations = len(state)

# Инициилизировать сети: целевую и политики
policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)

# Подгрузить в целевую сеть коэффициенты из сети политики
target_net.load_state_dict(policy_net.state_dict())

# Задать оптимайзер
optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)

# Инициализировать Replay Memory buffer
#memory = ReplayMemory(FULL_MEMORY_LENGTH)
memory = ReplayMemory_GPU(FULL_MEMORY_LENGTH, device)


steps_done = 0

#     массив длительности эпизода - пойдет в отчет о том, сколько продержался агент
episode_durations = []

# %%
# еpsilon-жадная стратегия выбора действия
def select_action(state):
    global steps_done  # глобальный шаги для убывания epsilon
#     случайное значение для определения какой шаг будем делать жадный или случайный
    sample = random.random()
    
#     установка порога принятия решения - уровня epsilon
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    
#     увеличиваем счетчик шагов
    steps_done += 1
    
#     если случайный порог больше epsilon-порога
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) вернет наибольшее значение столбца в каждой строке.
            # Второй столбец в результате max - это индекс того места, 
            # где был найден максимальный элемент, 
            # поэтому мы выбираем действие с наибольшим ожидаемым вознаграждением.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        # Иначы выбираем случайное дайствие
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
        #return torch.tensor([[env.action_space.sample()]], device=torch.device('cpu'), dtype=torch.long)

# %% [markdown]
# ## Training loop
#
# Обучение модели.
#
# Функция `optimize_model` выполняет один шаг оптимизации. Сначала она производит выборку, конкатенирует все тензоры в один, вычисляет
# $Q(s_t, a_t)$ и $V(s_{t+1}) = max_aQ(s_{t+1},a)$ и объединяет их в Loss. По определению мы задаем $V(s)=0$, если $s$ является терминальным состоянием. Для повышения устойчивости мы также используем целевую сеть для вычисления $V(s_{t+1})$. Целевая сеть обновляется на каждом шаге с помощью __мягкого обновления__, управляемого гиперпараметром `TAU`.
#
# ### Мягкое обновление целевой сети

# %%
def optimize_model(batch_size: int):
    if len(memory) < batch_size:
        return
    
    # Получить из памяти батч
    transitions = memory.sample(batch_size)
    # Преобразовать его в namedtuple
    batch = Transition(*zip(*transitions))

    # Вычислить маску нефинальных состояний и соединить элементы батча
    # (финальным состоянием должно быть то, после которого моделирование закончилось)

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                        batch.next_state)), device=device, dtype=torch.bool)
    
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    
    # Собираем батчи для состояний, действий и наград
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Вычислить Q(s_t, a) - модель вычисляет Q(s_t), 
    # затем мы выбираем столбцы предпринятых действий. 
    # Это те действия, которые были бы предприняты для каждого состояния партии в соответствии с policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Вычислить V(s_{t+1}) для всех следующих состояний.
    # Ожидаемые значения действий для не_финальных_следующих_состояний вычисляются 
    # на основе "старшей" целевой_сети; выбирается их наилучшее вознаграждение с помощью max(1)[0].
    # Это объединяется по маске, так что мы будем иметь либо ожидаемое значение состояния, 
    # либо 0, если состояние было финальным.
    next_state_values = torch.zeros(batch_size, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0]
    # Вычисляем ожидаемые Q значения
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Объединяем все в общий лосс
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Готовим градиент
    optimizer.zero_grad()
    loss.backward()
    # Обрезаем значения градиента - проблемма исчезающего/взрывающего градиента
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    
    optimizer.step()

# %% [markdown]
# Ниже представлен основной цикл обучения.
#
# В начале мы сбрасываем окружение и получаем тензор начального `state`. Затем мы выбираем действие, выполняем его, наблюдаем следующее состояние и вознаграждение (всегда 1) и один раз оптимизируем нашу модель. Когда эпизод заканчивается (модель не работает), мы перезапускаем цикл.
#
#
# `num_episodes` устанавливается равным 1500, если доступен графический процессор, в противном случае планируется 500 эпизодов, чтобы обучение не занимало слишком много времени. 500 эпизодов вполне недостаточно для того, чтобы наблюдать хороший результат на CartPole на алгоритме Double DQN.
#
# Обучение RL-агентов может быть случайным процессом, поэтому перезапуск обучения может дать лучшие результаты, если сходимость не наблюдается.

# %%
if torch.cuda.is_available():
    num_episodes = 1000
else:
    num_episodes = 15
total_reward = []


import cProfile

# Create a profiler object
profiler = cProfile.Profile()

# Start profiling
profiler.enable()


for i_episode in tqdm(range(num_episodes)):
    episode_reward = 0
    # Для каждого эпизода инициализируем начальное состояние
    state, info = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    
    # выполняем действия пока не получим флаг done
    # t - считает сколько шагов успели сделать пока шест не упал
    for t in count():
        # выбираем действие [0, 1]
        action = select_action(state)
        # Делаем шаг
        observation, reward, terminated, truncated, _ = env.step(action.item())
        episode_reward += reward

        # Преобразуем в тензор
        reward = torch.tensor([reward], device=device)
        
        # Объединяем done по двум конечным состояниям
        done = terminated or truncated
        
        # присваиваем следующее состояние
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # отправляем в память
        memory.push(state, action, next_state, reward)

        # переходим на следующее состояние
        state = next_state

        # запускаем обучение сети
        optimize_model(batch_size=128)

        # делаем "мягкое" обновление весов
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
        
        # Если получили terminated or truncated завершаем эпизод обучения
        if done:
            # добавляем в массив продолжительность эпизода
            episode_durations.append(t + 1)
            total_reward.append(episode_reward)
            break


        
# Stop profiling
profiler.disable()

# Print the profiling results
profiler.print_stats()

print('Complete')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]C:\Users\stepa\AppData\Local\Temp\ipykernel_12624\3660701389.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   transition = transition._replace(state=torch.tensor(transition.state, dtype=torch.float32).to(self.device) if transition.state is not None else None)
# C:\Users\stepa\AppData\Local\Temp\ipykernel_12624\3660701389.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   transition = transition._replace(action=torch.tensor(transition.action, dtype=torch.int64).to(self.device) if transition.action is not None else None)
# C:\Users\stepa\AppData\Local\Temp\ipykernel_12624\3660701389.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   transition = transition._replace(next_state=torch.tensor(transition.next_state, dtype=torch.float32).to(self.device) if transition.next_state is not None else None)
# C:\Users\stepa\AppData\Local\Temp\ipykernel_12624\3660701389.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   transition = transition._replace(reward=torch.tensor(transition.reward, dtype=torch.float32).to(self.device) if transition.reward is not None else None)
# 100%|██████████| 1000/1000 [55:16<00:00,  3.32s/it]
#          682448379 function calls (666872163 primitive calls) in 3315.691 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    942910   44.085    0.000  703.870    0.001 2270288748.py:12(forward)
#    320017  175.297    0.001 2143.242    0.007 3049369242.py:1(optimize_model)
#  40945920    4.916    0.000    4.916    0.000 3049369242.py:13(<lambda>)
#    319890    4.609    0.000    4.609    0.000 3049369242.py:16(<listcomp>)
#    320017    7.304    0.000  263.364    0.001 3316208243.py:2(select_action)
#   1599133    0.511    0.000    0.511    0.000 3660701389.py:10(<genexpr>)
#    319890    2.300    0.000  106.065    0.000 3660701389.py:18(sample)
#    320017    0.225    0.000    0.367    0.000 3660701389.py:21(__len__)
#    320017   11.188    0.000  108.495    0.000 3660701389.py:7(push)
#         1  357.920  357.920 3316.918 3316.918 3977268385.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1022(_find_and_load)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:391(cached)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:492(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:664(_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:746(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:893(__enter__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:897(__exit__)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:921(_find_spec)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1040(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1065(get_filename)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1070(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1089(path_stats)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1399(_get_spec)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1431(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1531(_get_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1536(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:380(cache_from_source)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:510(_get_cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:542(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:585(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:618(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:670(_compile_bytecode)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:721(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:874(create_module)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:877(exec_module)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:950(get_code)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#   1920102    1.244    0.000    2.238    0.000 <string>:1(<lambda>)
#    319890    0.516    0.000    0.516    0.000 <string>:2(__init__)
#      2000    0.005    0.000    0.032    0.000 Box2D.py:113(_init_jointdef_kwargs)
#     11000    0.019    0.000    0.062    0.000 Box2D.py:1704(__init__)
#     11000    0.021    0.000    0.023    0.000 Box2D.py:1744(__set_vertices)
#      3000    0.007    0.000    0.045    0.000 Box2D.py:1889(__init__)
#      1000    0.016    0.000    0.017    0.000 Box2D.py:1915(__set_vertices)
#      2000    0.003    0.000    0.003    0.000 Box2D.py:1946(<lambda>)
#      4000    0.010    0.000    0.050    0.000 Box2D.py:2207(__init__)
#      4000    0.003    0.000    0.003    0.000 Box2D.py:2238(__del__)
#     10000    0.002    0.000    0.002    0.000 Box2D.py:2246(fixtures)
#      3000    0.003    0.000    0.003    0.000 Box2D.py:2250(fixtures)
#      5000    0.001    0.000    0.001    0.000 Box2D.py:2257(shapes)
#      1000    0.002    0.000    0.003    0.000 Box2D.py:2261(shapes)
#      1000    0.000    0.000    0.000    0.000 Box2D.py:2268(shapeFixture)
#     10000    0.050    0.000    0.215    0.000 Box2D.py:2401(__CreateShapeFixture)
#     10000    0.021    0.000    0.241    0.000 Box2D.py:2452(CreateEdgeFixture)
#      1000    0.010    0.000    0.019    0.000 Box2D.py:2478(CreateFixturesFromShapes)
#     13000    0.027    0.000    0.028    0.000 Box2D.py:2512(CreateFixture)
#     14000    0.025    0.000    0.106    0.000 Box2D.py:2626(__init__)
#     14000    0.007    0.000    0.007    0.000 Box2D.py:2650(__del__)
#      3000    0.006    0.000    0.006    0.000 Box2D.py:2654(__SetCategoryBits)
#      3000    0.004    0.000    0.004    0.000 Box2D.py:2658(__SetMaskBits)
#      1000    0.007    0.000    0.017    0.000 Box2D.py:2887(__init__)
#      3000    0.009    0.000    0.078    0.000 Box2D.py:3125(CreateDynamicBody)
#      1000    0.005    0.000    0.059    0.000 Box2D.py:3145(CreateStaticBody)
#      4000    0.037    0.000    0.120    0.000 Box2D.py:3155(CreateBody)
#      2000    0.012    0.000    0.013    0.000 Box2D.py:3318(CreateJoint)
#      2000    0.006    0.000    0.006    0.000 Box2D.py:3366(__SetData)
#      2000    0.004    0.000    0.010    0.000 Box2D.py:3377(<lambda>)
#      2000    0.002    0.000    0.002    0.000 Box2D.py:3589(__del__)
#     43236    0.045    0.000    0.087    0.000 Box2D.py:429(b2BodyCompare)
#      2000    0.017    0.000    0.056    0.000 Box2D.py:4304(__init__)
#     37000    0.068    0.000    0.170    0.000 Box2D.py:99(_init_kwargs)
#    319890    0.512    0.000    0.812    0.000 _VF.py:26(__getattr__)
#   1600085    0.469    0.000    0.469    0.000 __future__.py:68(get_swap_module_params_on_conversion)
#    319890    0.798    0.000    4.890    0.000 __init__.py:101(_nvml_based_avail)
#    319890    0.822    0.000    6.547    0.000 __init__.py:105(is_available)
#    639780    0.222    0.000    0.222    0.000 __init__.py:127(annotate)
#    319890    0.421    0.000    0.421    0.000 __init__.py:155(_tensor_or_tensors_to_tuple)
#   6717690    3.964    0.000    5.039    0.000 __init__.py:157(is_compiling)
#    319890    3.666    0.000  434.527    0.001 __init__.py:165(backward)
#    319890    0.722    0.000    0.722    0.000 __init__.py:1710(getEffectiveLevel)
#    319890    0.292    0.000    0.292    0.000 __init__.py:33(is_built)
#         2    0.000    0.000    0.000    0.000 __init__.py:384(__getattr__)
#         2    0.000    0.000    0.000    0.000 __init__.py:391(__getitem__)
#   1280068    1.699    0.000    5.004    0.000 __init__.py:420(_make)
#   1280068    3.817    0.000    8.822    0.000 __init__.py:430(_replace)
#         1    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#    319890    4.814    0.000   27.327    0.000 __init__.py:60(_make_grads)
#    319890    0.338    0.000    0.562    0.000 __init__.py:96(_is_compiled)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#    319890    1.016    0.000    3.497    0.000 _collections_abc.py:816(get)
#    319890    3.902    0.000  126.400    0.000 _compile.py:20(inner)
#    639780    2.487    0.000   34.770    0.000 _contextlib.py:112(decorate_context)
#    639780    1.186    0.000    4.213    0.000 _contextlib.py:141(clone)
#   4142826    8.223    0.000   10.129    0.000 _contextlib.py:149(__new__)
#    319890    0.374    0.000    0.630    0.000 _foreach_utils.py:12(_get_fused_kernels_supported_devices)
#    639780    2.231    0.000   22.874    0.000 _foreach_utils.py:30(_group_tensors_by_device_and_dtype)
#    639780    1.193    0.000    1.861    0.000 _foreach_utils.py:35(<dictcomp>)
#    319890    3.696    0.000    4.593    0.000 _foreach_utils.py:42(_device_has_foreach_support)
#    319890    0.749    0.000    7.313    0.000 _foreach_utils.py:46(_has_foreach_support)
#   2879010    1.097    0.000    1.097    0.000 _foreach_utils.py:47(<genexpr>)
#    639780    0.783    0.000    1.184    0.000 _foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#  20777106    3.871    0.000    3.871    0.000 _jit_internal.py:1120(is_scripting)
#         1    0.000    0.000    0.003    0.003 _monitor.py:30(__init__)
#         1    0.000    0.000    0.000    0.000 _ops.py:43(__init__)
#         1    0.000    0.000    0.000    0.000 _ops.py:547(__init__)
#    639780    0.940    0.000    9.228    0.000 _ops.py:591(__call__)
#         1    0.000    0.000    0.000    0.000 _ops.py:800(__getattr__)
#    639780    1.284    0.000   21.825    0.000 _ops.py:846(__call__)
#    319890    0.331    0.000    0.331    0.000 _reduction.py:7(get_enum)
#   7677368    2.872    0.000    4.333    0.000 _tensor.py:1059(__hash__)
#    319890    3.273    0.000  437.913    0.001 _tensor.py:466(backward)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#   6717690    4.511    0.000    9.550    0.000 _utils.py:851(is_compiling)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:111(remove)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:63(__iter__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:86(add)
#    319891    0.314    0.000    1.027    0.000 abc.py:117(__instancecheck__)
# 320020/320018    0.464    0.000    1.083    0.000 abc.py:121(__subclasscheck__)
#    319890    4.143    0.000  277.249    0.001 adamw.py:152(step)
#    319890    8.718    0.000  239.172    0.001 adamw.py:280(adamw)
#   2879010    1.231    0.000    1.546    0.000 adamw.py:309(<genexpr>)
#    319890   12.319    0.000  218.289    0.001 adamw.py:480(_multi_tensor_adamw)
#    319890    3.457    0.000   15.953    0.000 adamw.py:595(<listcomp>)
#    319890    1.806    0.000    9.779    0.000 adamw.py:596(<listcomp>)
#    319890    0.582    0.000    0.582    0.000 adamw.py:598(<listcomp>)
#    319890    1.012    0.000    6.019    0.000 adamw.py:600(<listcomp>)
#    319890   14.742    0.000   20.823    0.000 adamw.py:91(_init_group)
#    959670    1.598    0.000    1.988    0.000 base.py:127(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 box.py:149(shape)
#         1    0.000    0.000    0.000    0.000 box.py:237(contains)
#    319890    5.924    0.000   92.960    0.000 clip_grad.py:116(clip_grad_value_)
#    319890    4.742    0.000   30.536    0.000 clip_grad.py:137(<listcomp>)
#    319890    3.651    0.000  104.148    0.000 clip_grad.py:18(_no_grad_wrapper)
#         2    0.000    0.000    0.000    0.000 codeop.py:117(__call__)
#         4    0.000    0.000    0.000    0.000 compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 context.py:197(get_start_method)
#         1    0.000    0.000    0.000    0.000 context.py:233(get_context)
#         1    0.000    0.000    0.002    0.002 context.py:70(RLock)
#         2    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 contextlib.py:63(_recreate_cm)
#         1    0.000    0.000    0.000    0.000 contextlib.py:76(inner)
#      1000    0.001    0.000    0.001    0.000 core.py:121(reset)
#    645034    0.473    0.000    0.473    0.000 core.py:215(np_random)
# 50661/16887    0.137    0.000    0.137    0.000 core.py:384(action_space)
#    639780    0.266    0.000    0.266    0.000 decorators.py:148(graph_break)
#    319890    2.209    0.000   79.605    0.000 decorators.py:36(disable)
#     16887    0.087    0.000    0.655    0.000 discrete.py:58(sample)
#    321017    4.828    0.000    4.928    0.000 discrete.py:94(contains)
#    320017    1.642    0.000   51.804    0.000 env_checker.py:45(step)
#      1000    0.009    0.000    0.915    0.001 env_checker.py:53(reset)
#    319890    0.701    0.000    0.964    0.000 eval_frame.py:119(backend_cache_manager)
#    319890    1.532    0.000    1.913    0.000 eval_frame.py:141(change)
#    319890    0.422    0.000    0.422    0.000 eval_frame.py:149(revert)
#    319890    0.104    0.000    0.104    0.000 eval_frame.py:257(nothing)
#    639780    0.136    0.000    0.136    0.000 eval_frame.py:261(always_false)
#    959670    0.780    0.000    1.186    0.000 eval_frame.py:265(innermost_fn)
#    319890    2.542    0.000    3.671    0.000 eval_frame.py:290(__init__)
#    319890    7.665    0.000   71.545    0.000 eval_frame.py:351(__call__)
#    319890    2.074    0.000   42.893    0.000 eval_frame.py:428(_fn)
#    319890    0.429    0.000    2.342    0.000 eval_frame.py:448(<listcomp>)
#    319890    1.336    0.000    5.007    0.000 eval_frame.py:550(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2416(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2421(all)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:71(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#   2828730    8.815    0.000  140.435    0.000 functional.py:1489(relu)
#    319890    3.394    0.000   49.018    0.000 functional.py:3229(smooth_l1_loss)
#    319890    2.890    0.000    6.124    0.000 functional.py:47(broadcast_tensors)
#    319890    2.096    0.000    3.675    0.000 functools.py:35(update_wrapper)
#         1    0.000    0.000    0.000    0.000 functools.py:393(__get__)
#    319890    0.790    0.000    0.790    0.000 functools.py:65(wraps)
#    319890    0.797    0.000   26.793    0.000 genericpath.py:16(exists)
#   8925432   15.407    0.000   28.997    0.000 grad_mode.py:183(__init__)
#   4142826   10.795    0.000   11.858    0.000 grad_mode.py:74(__init__)
#   4142826    7.196    0.000   19.990    0.000 grad_mode.py:79(__enter__)
#   4142826   10.215    0.000   26.081    0.000 grad_mode.py:83(__exit__)
#    319890    2.922    0.000  402.165    0.001 graph.py:739(_engine_run_backward)
#    319890    0.251    0.000    1.883    0.000 graphs.py:23(is_current_stream_capturing)
#    639780    0.740    0.000    0.836    0.000 inspect.py:182(ismodule)
#   1279560    0.701    0.000    0.898    0.000 inspect.py:191(isclass)
#    639780    0.499    0.000    0.589    0.000 inspect.py:199(ismethod)
#    639780    0.552    0.000    0.634    0.000 inspect.py:277(isfunction)
#    639780    0.414    0.000    0.591    0.000 inspect.py:355(istraceback)
#    639780    0.360    0.000    0.452    0.000 inspect.py:365(isframe)
#    639780    0.371    0.000    0.452    0.000 inspect.py:379(iscode)
#    639780    3.662    0.000    7.531    0.000 inspect.py:773(getfile)
#    319890    3.671    0.000   39.169    0.000 inspect.py:813(getsourcefile)
#    959670    0.725    0.000    1.202    0.000 inspect.py:820(<genexpr>)
#    959670    0.432    0.000    0.589    0.000 inspect.py:823(<genexpr>)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:1277(user_global_ns)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3493(compare)
#         2    0.000    0.000 3316.918 1658.459 interactiveshell.py:3541(run_code)
#      3012    0.004    0.000    0.004    0.000 iostream.py:138(_event_pipe)
#      3012    0.015    0.000    0.097    0.000 iostream.py:259(schedule)
#      1008    0.003    0.000    0.004    0.000 iostream.py:505(parent_header)
#      1008    0.003    0.000    0.004    0.000 iostream.py:550(_is_master_process)
#      1008    0.004    0.000    0.068    0.000 iostream.py:577(_schedule_flush)
#      1004    0.013    0.000    0.688    0.001 iostream.py:592(flush)
#      1008    0.020    0.000    0.098    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.001    0.001 ipkernel.py:768(init_closure)
#       194    0.001    0.000    0.004    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#        97    0.001    0.000    0.002    0.000 ipkernel.py:790(<setcomp>)
#   3771640   13.637    0.000  477.142    0.000 linear.py:115(forward)
#         4    0.000    0.000    0.000    0.000 linecache.py:26(getline)
#         4    0.000    0.000    0.000    0.000 linecache.py:36(getlines)
#    319890    1.653    0.000   14.077    0.000 loss.py:20(__init__)
#    319890    1.666    0.000   17.739    0.000 loss.py:934(__init__)
#    319890    1.256    0.000   50.274    0.000 loss.py:938(forward)
#      1000    0.018    0.000    0.027    0.000 lunar_lander.py:333(_destroy)
#      1000    0.122    0.000    0.906    0.001 lunar_lander.py:345(reset)
#      1000    0.003    0.000    0.003    0.000 lunar_lander.py:364(<listcomp>)
#      1000    0.011    0.000    0.011    0.000 lunar_lander.py:373(<listcomp>)
#      1000    0.003    0.000    0.003    0.000 lunar_lander.py:399(<listcomp>)
#      1000    0.002    0.000    0.002    0.000 lunar_lander.py:482(_clean_particles)
#    321017   30.864    0.000   50.258    0.000 lunar_lander.py:486(step)
#    321017    1.679    0.000   10.855    0.000 lunar_lander.py:537(<listcomp>)
#      1000    0.004    0.000    0.021    0.000 lunar_lander.py:61(__init__)
#      5184    0.108    0.000    0.169    0.000 lunar_lander.py:65(BeginContact)
#      3033    0.049    0.000    0.074    0.000 lunar_lander.py:75(EndContact)
# 5034440/1262800   11.293    0.000  771.891    0.001 module.py:1528(_wrapped_call_impl)
# 5034440/1262800   24.188    0.000  768.609    0.001 module.py:1534(_call_impl)
#  11314920   14.982    0.000   14.982    0.000 module.py:1696(__getattr__)
#    639780    3.305    0.000    6.632    0.000 module.py:1711(__setattr__)
#   3200170   13.223    0.000   28.854    0.000 module.py:1806(_save_to_state_dict)
# 3200170/640034   19.812    0.000   51.791    0.000 module.py:1845(state_dict)
#   1600085   61.303    0.000  207.014    0.000 module.py:1974(_load_from_state_dict)
#   1600085    0.509    0.000    0.509    0.000 module.py:2014(<dictcomp>)
#   1600085    2.618    0.000    2.618    0.000 module.py:2016(<dictcomp>)
#    320017    4.072    0.000  240.635    0.001 module.py:2103(load_state_dict)
# 1600085/320017   14.234    0.000  231.880    0.001 module.py:2153(load)
#   1280068    4.613    0.000    6.943    0.000 module.py:2162(<dictcomp>)
#   2879010    8.149    0.000   21.454    0.000 module.py:2193(_named_members)
#   2879010    2.105    0.000   25.794    0.000 module.py:2207(parameters)
#   2879010    2.234    0.000   23.688    0.000 module.py:2232(named_parameters)
#   1599450    1.391    0.000    1.784    0.000 module.py:2260(<lambda>)
# 4478460/1919340    6.672    0.000    7.442    0.000 module.py:2369(named_modules)
#    319890    6.011    0.000    7.787    0.000 module.py:428(__init__)
#         1    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:503(can_cast)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:283(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:357(issubdtype)
#    319890    1.228    0.000    8.750    0.000 optimizer.py:109(_default_to_fused_or_foreach)
#   2879010    5.619    0.000    5.619    0.000 optimizer.py:122(<genexpr>)
#         8    0.000    0.000    0.000    0.000 optimizer.py:135(_get_scalar_dtype)
#    319890    2.768    0.000   12.870    0.000 optimizer.py:327(_cuda_graph_capture_health_check)
#    319890    0.118    0.000    0.118    0.000 optimizer.py:358(_optimizer_step_code)
#    319890    7.849    0.000  314.538    0.001 optimizer.py:374(wrapper)
#    319890    0.598    0.000   20.958    0.000 optimizer.py:402(_group_tensors_by_device_and_dtype)
#    319890    4.521    0.000  284.245    0.001 optimizer.py:58(_use_grad)
#    319890   13.579    0.000   37.384    0.000 optimizer.py:793(zero_grad)
#   5118240    6.970    0.000   20.468    0.000 optimizer.py:84(_get_value)
#    319890    0.342    0.000    0.749    0.000 optimizer.py:91(_stack_if_compiling)
#   2559120    3.053    0.000    5.006    0.000 optimizer.py:97(_dispatch_sqrt)
#    320017    0.929    0.000   52.733    0.000 order_enforcing.py:52(step)
#      1000    0.004    0.000    0.919    0.001 order_enforcing.py:58(reset)
#    319890    1.430    0.000    2.481    0.000 os.py:674(__getitem__)
#    319890    0.237    0.000    0.298    0.000 os.py:740(check_str)
#    319890    0.538    0.000    1.051    0.000 os.py:746(encodekey)
#    319890    0.596    0.000    4.093    0.000 os.py:771(getenv)
#   2560136    1.714    0.000    1.714    0.000 overrides.py:1838(is_tensor_like)
#    639780    1.416    0.000    9.529    0.000 package_importer.py:694(_patched_getfile)
#   2560136    1.631    0.000    2.562    0.000 parameter.py:167(is_lazy)
#    639780    1.330    0.000    1.964    0.000 parameter.py:8(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 passive_env_checker.py:116(check_obs)
#         1    0.000    0.000    0.000    0.000 passive_env_checker.py:205(env_step_passive_checker)
#         1    0.000    0.000    0.000    0.000 process.py:37(current_process)
#    639780    3.334    0.000    4.689    0.000 profiler.py:593(__init__)
#    639780    3.242    0.000   25.067    0.000 profiler.py:604(__enter__)
#    639780    5.826    0.000   15.514    0.000 profiler.py:610(__exit__)
#         1    0.000    0.000    0.000    0.000 random.py:119(__init__)
#         1    0.000    0.000    0.000    0.000 random.py:128(seed)
#  41218733   34.309    0.000   48.980    0.000 random.py:239(_randbelow_with_getrandbits)
#    319890   45.328    0.000  103.765    0.000 random.py:406(sample)
#         1    0.000    0.000    0.000    0.000 random.py:506(choices)
#         1    0.000    0.000    0.000    0.000 random.py:519(<listcomp>)
#         1    0.000    0.000    0.000    0.000 random.py:826(getrandbits)
#         1    0.000    0.000    0.001    0.001 seeding.py:9(np_random)
#      3012    0.063    0.000    0.063    0.000 socket.py:626(send)
#         1    0.000    0.000    0.001    0.001 space.py:105(seed)
#         1    0.000    0.000    0.000    0.000 space.py:114(__contains__)
#     16887    0.014    0.000    0.015    0.000 space.py:66(np_random)
#      1005    0.005    0.000    0.010    0.000 std.py:102(acquire)
#      1005    0.004    0.000    0.007    0.000 std.py:106(release)
#         4    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         4    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         1    0.000    0.000    0.000    0.000 std.py:1147(__del__)
#      1002    0.007    0.000    0.112    0.000 std.py:1150(__str__)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         1    0.000    0.000    0.002    0.002 std.py:116(create_mp_lock)
#      1001    0.008    0.000    1.027    0.001 std.py:1160(__iter__)
#      1000    0.018    0.000    1.018    0.001 std.py:1198(update)
#         2    0.000    0.000    0.001    0.000 std.py:1265(close)
#         2    0.000    0.000    0.000    0.000 std.py:1286(fp_write)
#         1    0.000    0.000    0.000    0.000 std.py:1301(<lambda>)
#      1001    0.007    0.000    0.991    0.001 std.py:1325(refresh)
#      1002    0.010    0.000    0.013    0.000 std.py:1446(format_dict)
#      1002    0.007    0.000    0.969    0.001 std.py:1464(display)
#      1002    0.003    0.000    0.004    0.000 std.py:153(__init__)
#      1002    0.000    0.000    0.000    0.000 std.py:163(colour)
#      1002    0.001    0.000    0.001    0.000 std.py:167(colour)
#      1002    0.006    0.000    0.007    0.000 std.py:186(__format__)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#      5959    0.012    0.000    0.012    0.000 std.py:231(__call__)
#      2003    0.010    0.000    0.011    0.000 std.py:400(format_interval)
#         1    0.000    0.000    0.001    0.001 std.py:438(status_printer)
#      1002    0.005    0.000    0.795    0.001 std.py:451(fp_write)
#      1002    0.005    0.000    0.849    0.001 std.py:457(print_status)
#      1002    0.045    0.000    0.092    0.000 std.py:464(format_meter)
#         1    0.000    0.000    0.005    0.005 std.py:663(__new__)
#         1    0.000    0.000    0.000    0.000 std.py:679(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 std.py:682(<setcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:686(_decr_instances)
#         1    0.000    0.000    0.002    0.002 std.py:760(get_lock)
#         1    0.000    0.000    0.002    0.002 std.py:90(__init__)
#         1    0.000    0.000    0.002    0.002 std.py:952(__init__)
#         1    0.000    0.000    0.000    0.000 std.py:98(<listcomp>)
#         1    0.000    0.000    0.000    0.000 synchronize.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 synchronize.py:114(_make_name)
#         1    0.000    0.000    0.000    0.000 synchronize.py:123(Semaphore)
#         1    0.000    0.000    0.000    0.000 synchronize.py:142(BoundedSemaphore)
#         1    0.000    0.000    0.000    0.000 synchronize.py:159(Lock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:184(RLock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:210(Condition)
#         1    0.000    0.000    0.000    0.000 synchronize.py:321(Event)
#         1    0.000    0.000    0.000    0.000 synchronize.py:360(Barrier)
#         1    0.000    0.000    0.000    0.000 synchronize.py:46(SemLock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:50(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#         1    0.000    0.000    0.000    0.000 tempfile.py:142(rng)
#         1    0.000    0.000    0.000    0.000 tempfile.py:153(__next__)
#      4016    0.005    0.000    0.008    0.000 threading.py:1095(_wait_for_tstate_lock)
#      2686    0.002    0.000    0.002    0.000 threading.py:1138(ident)
#      4016    0.009    0.000    0.018    0.000 threading.py:1162(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:1176(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1191(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1294(_make_invoke_excepthook)
#      1005    0.002    0.000    0.003    0.000 threading.py:1423(current_thread)
#        97    0.001    0.000    0.001    0.000 threading.py:1471(enumerate)
#      1006    0.010    0.000    0.010    0.000 threading.py:236(__init__)
#      1005    0.001    0.000    0.002    0.000 threading.py:264(__enter__)
#      1005    0.001    0.000    0.002    0.000 threading.py:267(__exit__)
#      1001    0.001    0.000    0.001    0.000 threading.py:273(_release_save)
#      1001    0.002    0.000    0.002    0.000 threading.py:276(_acquire_restore)
#      1001    0.001    0.000    0.001    0.000 threading.py:279(_is_owned)
#      1001    0.008    0.000    0.604    0.001 threading.py:288(wait)
#      1006    0.004    0.000    0.019    0.000 threading.py:538(__init__)
#      4018    0.001    0.000    0.001    0.000 threading.py:546(is_set)
#      1005    0.008    0.000    0.615    0.001 threading.py:582(wait)
#         1    0.000    0.000    0.000    0.000 threading.py:775(_newname)
#         1    0.001    0.001    0.001    0.001 threading.py:820(__init__)
#         1    0.000    0.000    0.001    0.001 threading.py:909(start)
#    320017    2.585    0.000   55.318    0.000 time_limit.py:46(step)
#      1000    0.005    0.000    0.924    0.001 time_limit.py:65(reset)
#    319890    1.381    0.000    1.486    0.000 trace_rules.py:2840(is_aten_op_or_tensor_method)
#    319890    2.087    0.000    4.173    0.000 trace_rules.py:3275(check_file)
#   1279560    0.857    0.000    1.331    0.000 trace_rules.py:3279(<genexpr>)
#    319890    2.997    0.000   18.726    0.000 trace_rules.py:3342(check_verbose)
#    319890    0.565    0.000   19.291    0.000 trace_rules.py:3377(check)
#    319890    1.684    0.000    8.072    0.000 trace_rules.py:3432(lookup_inner)
#         2    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 typing.py:1016(__init__)
#         3    0.000    0.000    0.000    0.000 typing.py:1022(<genexpr>)
#    320017    0.733    0.000    2.614    0.000 typing.py:1153(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 typing.py:137(_type_convert)
#         3    0.000    0.000    0.000    0.000 typing.py:146(_type_check)
#   1279564    0.340    0.000    0.340    0.000 typing.py:1736(cast)
#         1    0.000    0.000    0.000    0.000 typing.py:253(_deduplicate)
#         1    0.000    0.000    0.000    0.000 typing.py:267(_remove_dups_flatten)
# 1599451/1599450    2.363    0.000    2.363    0.000 typing.py:306(inner)
#         1    0.000    0.000    0.000    0.000 typing.py:380(__repr__)
#       2/1    0.000    0.000    0.000    0.000 typing.py:401(__getitem__)
#         1    0.000    0.000    0.000    0.000 typing.py:483(Union)
#         3    0.000    0.000    0.000    0.000 typing.py:515(<genexpr>)
#         1    0.000    0.000    0.000    0.000 typing.py:523(Optional)
#         1    0.000    0.000    0.000    0.000 typing.py:664(__init__)
#        13    0.000    0.000    0.000    0.000 typing.py:705(__eq__)
#         2    0.000    0.000    0.000    0.000 typing.py:714(__hash__)
#         8    0.000    0.000    0.000    0.000 typing.py:935(_is_dunder)
#         1    0.000    0.000    0.000    0.000 typing.py:947(__init__)
#         8    0.000    0.000    0.000    0.000 typing.py:986(__setattr__)
#    320017    0.852    0.000    3.465    0.000 typing.py:993(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 typing_extensions.py:151(_should_collect_from_parameters)
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2731(_collect_type_vars)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#      1002    0.001    0.000    0.001    0.000 utils.py:108(__init__)
#      1002    0.001    0.000    0.001    0.000 utils.py:112(__format__)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#      2006    0.006    0.000    0.791    0.000 utils.py:194(inner)
#         1    0.000    0.000    0.000    0.000 utils.py:213(__init__)
#         4    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         1    0.000    0.000    0.000    0.000 utils.py:266(_supports_unicode)
#      2004    0.008    0.000    0.012    0.000 utils.py:273(_is_ascii)
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 utils.py:297(_screen_shape_windows)
#      1002    0.002    0.000    0.041    0.000 utils.py:374(_text_width)
#     51276    0.020    0.000    0.029    0.000 utils.py:375(<genexpr>)
#      1002    0.003    0.000    0.048    0.000 utils.py:378(disp_len)
#    319890    0.346    0.000    0.494    0.000 utils.py:435(hashable)
#    319890    0.531    0.000    4.144    0.000 utils.py:862(getfile)
#         4    0.000    0.000    0.000    0.000 warnings.py:117(_formatwarnmsg)
#         4    0.000    0.000    0.000    0.000 warnings.py:20(_showwarnmsg_impl)
#         4    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#         4    0.000    0.000    0.000    0.000 warnings.py:403(__init__)
#         4    0.000    0.000    0.000    0.000 warnings.py:96(_showwarnmsg)
#     43236    0.030    0.000    0.030    0.000 {built-in method Box2D._Box2D.__bodyeq}
#      4000    0.006    0.000    0.006    0.000 {built-in method Box2D._Box2D.b2BodyDef_swiginit}
#      1000    0.005    0.000    0.005    0.000 {built-in method Box2D._Box2D.b2ContactListener_swiginit}
#     11000    0.016    0.000    0.016    0.000 {built-in method Box2D._Box2D.b2EdgeShape_swiginit}
#     14000    0.016    0.000    0.016    0.000 {built-in method Box2D._Box2D.b2FixtureDef_swiginit}
#      3000    0.006    0.000    0.006    0.000 {built-in method Box2D._Box2D.b2PolygonShape_swiginit}
#      2000    0.004    0.000    0.004    0.000 {built-in method Box2D._Box2D.b2RevoluteJointDef_swiginit}
#      4000    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.new_b2BodyDef}
#      1000    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.new_b2ContactListener}
#     11000    0.006    0.000    0.006    0.000 {built-in method Box2D._Box2D.new_b2EdgeShape}
#     14000    0.006    0.000    0.006    0.000 {built-in method Box2D._Box2D.new_b2FixtureDef}
#      3000    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.new_b2PolygonShape}
#      2000    0.002    0.000    0.002    0.000 {built-in method Box2D._Box2D.new_b2RevoluteJointDef}
#   7982904    6.368    0.000    6.368    0.000 {built-in method __new__ of type object at 0x00007FFDDB109920}
#    319891    0.713    0.000    0.713    0.000 {built-in method _abc._abc_instancecheck}
# 320020/320018    0.619    0.000    0.619    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#      2009    0.007    0.000    0.007    0.000 {built-in method _thread.allocate_lock}
#      1008    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#    642886    0.201    0.000    0.201    0.000 {built-in method builtins.abs}
#    959670    2.563    0.000   10.825    0.000 {built-in method builtins.all}
#   1279687    2.094    0.000    5.603    0.000 {built-in method builtins.any}
#    959670    0.284    0.000    0.284    0.000 {built-in method builtins.callable}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#      5008    0.002    0.000    0.002    0.000 {built-in method builtins.divmod}
#       3/2    0.000    0.000 3316.918 1658.459 {built-in method builtins.exec}
#   9658755    3.842    0.000    3.842    0.000 {built-in method builtins.getattr}
#   5171528    1.754    0.000    1.754    0.000 {built-in method builtins.hasattr}
#    319892    0.148    0.000    0.148    0.000 {built-in method builtins.hash}
#   7997260    1.594    0.000    1.594    0.000 {built-in method builtins.id}
# 21875781/20595967    8.361    0.000   16.339    0.000 {built-in method builtins.isinstance}
#    320023    0.574    0.000    1.656    0.000 {built-in method builtins.issubclass}
# 17621580/17301563    4.028    0.000    4.253    0.000 {built-in method builtins.len}
#      1004    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#     21042    0.003    0.000    0.003    0.000 {built-in method builtins.ord}
#   1689454    0.508    0.000    0.568    0.000 {built-in method builtins.setattr}
#      1002    0.010    0.000    0.039    0.000 {built-in method builtins.sum}
#         4    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 {built-in method fromtimestamp}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#    319890    0.225    0.000    0.225    0.000 {built-in method math.ceil}
#    321017    0.228    0.000    0.228    0.000 {built-in method math.cos}
#    320017    0.375    0.000    0.375    0.000 {built-in method math.exp}
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#    319890    0.630    0.000    0.630    0.000 {built-in method math.log}
#    321017    0.417    0.000    0.417    0.000 {built-in method math.sin}
#   2559120    0.803    0.000    0.803    0.000 {built-in method math.sqrt}
#      1001    0.003    0.000    0.003    0.000 {built-in method now}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#      1009    0.001    0.000    0.001    0.000 {built-in method nt.getpid}
#    319893   25.996    0.000   25.996    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.urandom}
#    321017    2.424    0.000    2.424    0.000 {built-in method numpy.array}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#      4002    0.002    0.000    0.002    0.000 {built-in method time.time}
#    319890    0.593    0.000    0.593    0.000 {built-in method torch._C._are_functorch_transforms_active}
#    319890    0.273    0.000    0.273    0.000 {built-in method torch._C._cuda_getDeviceCount}
#    319890    1.632    0.000    1.632    0.000 {built-in method torch._C._cuda_isCurrentStreamCapturing}
#    639780    0.536    0.000    0.536    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_operation_overload}
#    959670    0.657    0.000    0.657    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_schema}
#   5034440   15.114    0.000   15.114    0.000 {built-in method torch._C._get_tracing_state}
#    639780   18.569    0.000   18.569    0.000 {built-in method torch._C._group_tensors_by_device_and_dtype}
#   3148620    1.856    0.000    1.856    0.000 {built-in method torch._C._has_torch_function_unary}
#    319890    0.140    0.000    0.140    0.000 {built-in method torch._C._has_torch_function_variadic}
#    319890    0.168    0.000    0.168    0.000 {built-in method torch._C._has_torch_function}
#    319890    1.777    0.000    1.777    0.000 {built-in method torch._C._log_api_usage_once}
#   3771640  457.882    0.000  457.882    0.000 {built-in method torch._C._nn.linear}
#    319890   38.148    0.000   38.148    0.000 {built-in method torch._C._nn.smooth_l1_loss}
#   8925432   10.453    0.000   10.453    0.000 {built-in method torch._C._set_grad_enabled}
#    639780   22.263    0.000   22.263    0.000 {built-in method torch._foreach_add_}
#    319890   14.766    0.000   14.766    0.000 {built-in method torch._foreach_addcdiv_}
#    319890   13.724    0.000   13.724    0.000 {built-in method torch._foreach_addcmul_}
#    319890   12.311    0.000   12.311    0.000 {built-in method torch._foreach_clamp_max_}
#    319890   20.033    0.000   20.033    0.000 {built-in method torch._foreach_clamp_min_}
#    319890   11.906    0.000   11.906    0.000 {built-in method torch._foreach_div_}
#    319890   14.256    0.000   14.256    0.000 {built-in method torch._foreach_lerp_}
#    319890   13.831    0.000   13.831    0.000 {built-in method torch._foreach_maximum_}
#    639780   26.262    0.000   26.262    0.000 {built-in method torch._foreach_mul_}
#    319890   24.846    0.000   24.846    0.000 {built-in method torch._foreach_sqrt}
#    639780   20.542    0.000   20.542    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#    639780    8.287    0.000    8.287    0.000 {built-in method torch._ops.profiler.}
#    319890    2.254    0.000    2.254    0.000 {built-in method torch.broadcast_tensors}
#   1279560  198.291    0.000  198.291    0.000 {built-in method torch.cat}
#         8    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#   2559120    1.927    0.000    1.927    0.000 {built-in method torch.is_complex}
#  13388148    5.008    0.000    5.008    0.000 {built-in method torch.is_grad_enabled}
#    319890   21.575    0.000   21.575    0.000 {built-in method torch.ones_like}
#   2828730  129.878    0.000  129.878    0.000 {built-in method torch.relu}
#   2575873  176.705    0.000  176.705    0.000 {built-in method torch.tensor}
#        24    0.002    0.000    0.002    0.000 {built-in method torch.zeros_like}
#    319890   18.515    0.000   18.515    0.000 {built-in method torch.zeros}
#     50274    0.009    0.000    0.009    0.000 {built-in method unicodedata.east_asian_width}
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x000001E4A75785E0}
#         1    0.000    0.000    0.000    0.000 {function SeedSequence.generate_state at 0x000001E4C1A23F40}
#   2559120    0.782    0.000    0.782    0.000 {function _ParameterMeta.__instancecheck__ at 0x000001E4CA173F40}
#      1005    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#      1106    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#      1007    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#    639780    0.261    0.000    0.261    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#      1005    0.003    0.000    0.003    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#      1006    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.RLock' objects}
#      8020    0.593    0.000    0.593    0.000 {method 'acquire' of '_thread.lock' objects}
#  44986990    8.561    0.000    9.725    0.000 {method 'add' of 'set' objects}
#    324030    3.825    0.000    3.825    0.000 {method 'append' of 'collections.deque' objects}
#  15689620    2.560    0.000    2.560    0.000 {method 'append' of 'list' objects}
#  41218733    5.080    0.000    5.080    0.000 {method 'bit_length' of 'int' objects}
#   2560136   90.523    0.000   90.523    0.000 {method 'copy_' of 'torch._C.TensorBase' objects}
#   5120272   13.818    0.000   13.818    0.000 {method 'detach' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#   1279585    0.633    0.000    0.633    0.000 {method 'endswith' of 'str' objects}
#      2004    0.007    0.000    0.014    0.000 {method 'format' of 'str' objects}
#    319890   20.615    0.000   20.615    0.000 {method 'gather' of 'torch._C.TensorBase' objects}
#      1008    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#   6079184    2.116    0.000    2.116    0.000 {method 'get' of 'dict' objects}
#  67314772    9.591    0.000    9.591    0.000 {method 'getrandbits' of '_random.Random' objects}
#     16887    0.553    0.000    0.553    0.000 {method 'integers' of 'numpy.random._generator.Generator' objects}
#   5438257   41.168    0.000   41.168    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#  18879733    3.378    0.000    3.378    0.000 {method 'items' of 'collections.OrderedDict' objects}
#   4207850    0.913    0.000    0.913    0.000 {method 'items' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#    320017    0.068    0.000    0.068    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#   1280456    0.419    0.000    0.419    0.000 {method 'keys' of 'dict' objects}
#    623020   37.090    0.000   37.090    0.000 {method 'max' of 'torch._C.TensorBase' objects}
#    319890    0.468    0.000    0.468    0.000 {method 'numel' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#    320025    0.189    0.000    0.189    0.000 {method 'random' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1005    0.002    0.000    0.002    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#      1006    0.001    0.000    0.001    0.000 {method 'release' of '_thread.RLock' objects}
#      1001    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#    319890  398.521    0.001  398.521    0.001 {method 'run_backward' of 'torch._C._EngineBase' objects}
#    319890    0.248    0.000    0.248    0.000 {method 'setdefault' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#    639780    0.881    0.000    0.881    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#   5120273    1.853    0.000    1.853    0.000 {method 'split' of 'str' objects}
#  16320510    4.967    0.000    4.967    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#      1002    0.004    0.000    0.004    0.000 {method 'sub' of 're.Pattern' objects}
#   1279116    7.885    0.000    7.885    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#    645034    8.759    0.000    8.759    0.000 {method 'uniform' of 'numpy.random._generator.Generator' objects}
#    639955    6.931    0.000    6.931    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#    320892    0.167    0.000    0.167    0.000 {method 'update' of 'dict' objects}
#    319890    0.215    0.000    0.215    0.000 {method 'upper' of 'str' objects}
#  10880070    2.252    0.000    2.252    0.000 {method 'values' of 'collections.OrderedDict' objects}
#    320084    0.131    0.000    0.131    0.000 {method 'values' of 'dict' objects}
#    303130    4.845    0.000    4.845    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#      1008    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# Complete

# %%
# Вычисление скользящего среднего
window_size = 20
moving_avg = np.convolve(total_reward, np.ones(window_size)/window_size, mode='valid')
plt.plot(moving_avg)
plt.title('DQN + ReplayBuffer')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()

# %%
# Вычисление скользящего среднего
window_size = 20
moving_avg = np.convolve(total_reward, np.ones(window_size)/window_size, mode='valid')
plt.plot(moving_avg)
plt.title('DQN + ReplayBuffer')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()
